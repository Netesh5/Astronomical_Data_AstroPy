# %% [markdown]
# <a href="https://colab.research.google.com/github/Netesh5/Astronomical_Data_AstroPy/blob/main/Astropy_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/mydrive")
# Out:
# Mounted at /content/mydrive

# %%
from astropy.visualization import make_lupton_rgb
import matplotlib.pyplot as plt
from astropy.io import fits

# %%
image_r=fits.getdata("/content/mydrive/My Drive/Machine Learning/Astronomy/h_pu4k2bs01_f814w_sci_v20.fits")/2
image_g=fits.getdata("/content/mydrive/My Drive/Machine Learning/Astronomy/h_pu4k2bs01_f606w_sci_v20.fits")/3
image_b=fits.getdata("/content/mydrive/My Drive/Machine Learning/Astronomy/h_pu4k2bs01_f450w_sci_v20.fits")
image = make_lupton_rgb(image_r, image_g, image_b, stretch = 0.03, Q=10, filename='lmc.jpg')
plt.imshow(image,origin='lower')
